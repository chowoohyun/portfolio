# %%
import keras
import glob
import matplotlib.pyplot as plt

tmp = glob.glob('.\\asl\\test\\test\\*.jpg')

img = keras.preprocessing.image.load_img(tmp[1], target_size=(75,75))
plt.imshow(img)

# img_array = keras.preprocessing.image.img_to_array(img)
# #print(np.shape(img_array))

# img_array = tf.expand_dims(img_array, 0) # Create a batch
# #print(np.shape(img_array))

# predictions_v = model_VGG16.predict(img_array)
# predictions_m = model_MobileNet.predict(img_array)
# predictions_i = model_inception_V3.predict(img_array)

# score_v = tf.nn.softmax(predictions_v[0])
# score_m = tf.nn.softmax(predictions_m[0])
# score_i = tf.nn.softmax(predictions_i[0])


# print(
#     "(VGG16_MODEL) This image most likely belongs to {} with a {:.2f} percent confidence."
#     .format(class_names[np.argmax(score_v)], 100 * np.max(score_v)),'\n',
#     "(moblie_MODEL) This image most likely belongs to {} with a {:.2f} percent confidence."
#     .format(class_names[np.argmax(score_m)], 100 * np.max(score_m)),'\n',
#     "(Inception_MODEL) This image most likely belongs to {} with a {:.2f} percent confidence."
#     .format(class_names[np.argmax(score_i)], 100 * np.max(score_i)),
# )
# Out:
# .\asl\test\test\B_test.jpg

# %%
tmp[1].split('\\')
# Out:
# ['.', 'asl', 'test', 'test', 'B_test.jpg']

# %%
tmp[1].split('\\')[4].split('.')[0]
# Out:
# 'B_test'

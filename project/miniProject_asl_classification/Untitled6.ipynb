# %%
import glob
import os
# Out:
# ['g.jpg']

# %%
tmp_list = glob.glob(".\\asl\\train\\sample\\*.jpg")

for i in range(len(tmp_list)):
    tmp = tmp_list[i].split('\\')
    tmp = tmp[-1].split('(')
    tmp = tmp[0]
    print(tmp)
# Out:
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g.jpg
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# ...

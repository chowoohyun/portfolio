# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib import rc
import seaborn as sns
import pathlib
from collections import Counter
from wordcloud import WordCloud

plt.rcParams["axes.unicode_minus"] = False
rc("font", family = "Arial Unicode MS")
# %matplotlib inline 
get_ipython().run_line_magic("matplotlib","inline")

# %%
train = pd.read_csv('C:\\Users\\HP\\Desktop\\rapa\\fifa_data\\FIFA_train.csv')

# %%
train.head()
# Out:
#    id          name  age      continent contract_until position prefer_foot  \
# 0   0      L. Messi   31  south america           2021       ST        left
# 1   3        De Gea   27         europe           2020       GK       right
# 2   7     L. Suárez   31  south america           2021       ST       right
# 3   8  Sergio Ramos   32         europe           2020       DF       right
# 4   9      J. Oblak   25         europe           2021       GK       right
#
#    reputation  stat_overall  stat_potential  stat_skill_moves        value
# 0         5.0            94              94               4.0  110500000.0
# 1         4.0            91              93               1.0   72000000.0
# 2         5.0            91              91               3.0   80000000.0
# 3         4.0            91              91               3.0   51000000.0
# 4         3.0            90              93               1.0   68000000.0

# %%
#name& value
name_value=train[['name','value']]

# %%
name_value.head()
# Out:
#            name        value
# 0      L. Messi  110500000.0
# 1        De Gea   72000000.0
# 2     L. Suárez   80000000.0
# 3  Sergio Ramos   51000000.0
# 4      J. Oblak   68000000.0

# %%
#age&value
age_value=train[['age','value']]

# %%
#continent&value
continent_value=train[['continent','value']]

# %%
#postion&value
position_value=train[['position','value']]

# %%
#postion&age
position_age=train[['position','age']]

# %%
name_value['value'].sum()
# Out:
# 24819110000.0

# %%
name_value['value']=name_value['value']/10000.0
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2328\1265124376.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   name_value['value']=name_value['value']/10000.0

# %%
name_value
# Out:
#                     name    value
# 0               L. Messi  11050.0
# 1                 De Gea   7200.0
# 2              L. Suárez   8000.0
# 3           Sergio Ramos   5100.0
# 4               J. Oblak   6800.0
# ...                  ...      ...
# 8927          S. Adewusi      6.0
# 8928           C. Ehlich      4.0
# 8929          N. Fuentes      5.0
# 8930            J. Milli      5.0
# 8931  N. Christoffersson      6.0
#
# [8932 rows x 2 columns]

# %%
#count라는 데이터프레임을 사전형으로 변환
data = dict(zip(name_value['name'].tolist(), name_value['value'].tolist()))

wc = WordCloud(font_path='C:\windows/fonts/malgun.ttf', #폰트
               background_color='white',                              #배경색
               width=800, height=600 ,                                #사이즈설정
               max_words=200)                                         #단어갯수
cloud = wc.generate_from_frequencies(data)                            #사전형태 데이터

plt.figure(figsize=(10,10))                                           #액자사이즈설정
plt.axis('off')                                                       #테두리 선 없애기
plt.imshow(cloud,interpolation="bilinear")

# %%
icon = Image.open('toppp.png')    # 마스크가 될 이미지 불러오기 
plt.imshow(icon)

mask = Image.new("RGB", icon.size, (255,255,255))
mask.paste(icon,icon)
mask = np.array(mask)

# %%
wc = WordCloud(font_path='C:\windows/fonts/malgun.ttf',               #폰트
               background_color='white',                              #배경색
               width=800, height=600 ,                                #사이즈설정
               max_words=200,                                         #단어갯수
               mask=mask)                                             #마스크설정   

cloud = wc.generate_from_frequencies(data)                            #사전형태의 데이터

plt.figure(figsize=(10,10))                                           #액자사이즈설정
plt.axis('off')                                                       #테두리 선 없애기
plt.imshow(cloud,interpolation="bilinear")

# %%
icon = Image.open('ball.png')
plt.imshow(icon)

mask = Image.new("RGB", icon.size, (255,255,255))
mask.paste(icon,icon)
mask = np.array(mask)

# %%
wc = WordCloud(font_path='C:\windows/fonts/malgun.ttf', #폰트
               background_color='white',                              #배경색
               width=800, height=600 ,                                #사이즈설정
               max_words=200,                                         #단어갯수
               mask=mask)                                             #마스크설정   

cloud = wc.generate_from_frequencies(data)                            #사전형태의 데이터

plt.figure(figsize=(10,10))                                           #액자사이즈설정
plt.axis('off')                                                       #테두리 선 없애기
plt.imshow(cloud,interpolation="bilinear")

# %%
icon = Image.open('kick.png')
plt.imshow(icon)

mask = Image.new("RGB", icon.size, (255,255,255))
mask.paste(icon,icon)
mask = np.array(mask)

# %%
wc = WordCloud(font_path='C:\windows/fonts/malgun.ttf', #폰트
               background_color='white',                              #배경색
               width=800, height=600 ,                                #사이즈설정
               max_words=200,                                         #단어갯수
               mask=mask)                                             #마스크설정   

cloud = wc.generate_from_frequencies(data)                            #사전형태의 데이터

plt.figure(figsize=(10,10))                                           #액자사이즈설정
plt.axis('off')                                                       #테두리 선 없애기
plt.imshow(cloud,interpolation="bilinear")

# %%
def grey_color_func(word, font_size, position,orientation,random_state=None, **kwargs):
    return("hsl(0,0%%, %d%%)" % np.random.randint(60,100))    ## 색상코드/숫자를 조정해보세요
                                                            ## hsl 색상코드 참고

plt.imshow(cloud.recolor(color_func = grey_color_func),interpolation="bilinear")

# %%
def grey_color_func(word, font_size, position,orientation,random_state=None, **kwargs):
    return("hsl(151,58%%, %d%%)" % np.random.randint(60,100))  ## 색상코드/숫자를 조정해보세요
                                                            ## hsl 색상코드 참고

plt.imshow(cloud.recolor(color_func = grey_color_func),interpolation="bilinear")

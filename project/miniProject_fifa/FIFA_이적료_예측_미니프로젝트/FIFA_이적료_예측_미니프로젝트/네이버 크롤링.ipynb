# %%
# !pip install webdriver-manager

# %%
# !pip install selenium

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
'''
data는 4년전 데이터
'''
# Out:
# '\ndata는 4년전 데이터\n'

# %%
data = pd.read_csv("FIFA_train.csv")
data.head()
# Out:
#    id          name  age      continent contract_until position prefer_foot  \
# 0   0      L. Messi   31  south america           2021       ST        left
# 1   3        De Gea   27         europe           2020       GK       right
# 2   7     L. Suárez   31  south america           2021       ST       right
# 3   8  Sergio Ramos   32         europe           2020       DF       right
# 4   9      J. Oblak   25         europe           2021       GK       right
#
#    reputation  stat_overall  stat_potential  stat_skill_moves        value
# 0         5.0            94              94               4.0  110500000.0
# 1         4.0            91              93               1.0   72000000.0
# 2         5.0            91              91               3.0   80000000.0
# 3         4.0            91              91               3.0   51000000.0
# 4         3.0            90              93               1.0   68000000.0

# %%
# data['name'].str.split('.')

# %%
data['name_num'] = data['name'].apply(lambda x: len(x.split('.')))
data[data['name_num'] >= 3]   # .으로 split했을때 길이가 3이상인 데이터는 없음
# Out:
# Empty DataFrame
# Columns: [id, name, age, continent, contract_until, position, prefer_foot, reputation, stat_overall, stat_potential, stat_skill_moves, value, name_num]
# Index: []

# %%
data
# Out:
#          id                name  age      continent contract_until position  \
# 0         0            L. Messi   31  south america           2021       ST
# 1         3              De Gea   27         europe           2020       GK
# 2         7           L. Suárez   31  south america           2021       ST
# 3         8        Sergio Ramos   32         europe           2020       DF
# 4         9            J. Oblak   25         europe           2021       GK
# ...     ...                 ...  ...            ...            ...      ...
# 8927  16925          S. Adewusi   18         africa           2019       MF
# 8928  16936           C. Ehlich   19         europe           2020       DF
# 8929  16941          N. Fuentes   18  south america           2021       DF
# 8930  16942            J. Milli   18         europe           2021       GK
# 8931  16948  N. Christoffersson   19         europe           2020       ST
#
# ...

# %%
data['Fake_start_name'] = data['name'].apply(lambda x: x.split('.')[0] if len(x.split('.')) >= 2 else x[:1])
data['Fake_end_name'] = data['name'].apply(lambda x: x.split('.')[1] if len(x.split('.')) >= 2 else x)

data['2022age'] = data['age']+4
data[['Fake_start_name','Fake_end_name','2022age']]
# Out:
#      Fake_start_name     Fake_end_name  2022age
# 0                  L             Messi       35
# 1                  D            De Gea       31
# 2                  L            Suárez       35
# 3                  S      Sergio Ramos       36
# 4                  J             Oblak       29
# ...              ...               ...      ...
# 8927               S           Adewusi       22
# 8928               C            Ehlich       23
# 8929               N           Fuentes       22
# 8930               J             Milli       22
# 8931               N   Christoffersson       23
#
# [8932 rows x 3 columns]

# %%
fake_data = data[['name','name_num','Fake_start_name','Fake_end_name','2022age','continent']]
# fake_data.to_csv("Fake_data.csv", index=False)

# %%
Fake_data = pd.read_csv('Fake_data')
Fake_data
# Out:
#                     name  name_num Fake_start_name     Fake_end_name  2022age  \
# 0               L. Messi         2               L             Messi       35
# 1                 De Gea         1               D            De Gea       31
# 2              L. Suárez         2               L            Suárez       35
# 3           Sergio Ramos         1               S      Sergio Ramos       36
# 4               J. Oblak         2               J             Oblak       29
# ...                  ...       ...             ...               ...      ...
# 8927          S. Adewusi         2               S           Adewusi       22
# 8928           C. Ehlich         2               C            Ehlich       23
# 8929          N. Fuentes         2               N           Fuentes       22
# 8930            J. Milli         2               J             Milli       22
# 8931  N. Christoffersson         2               N   Christoffersson       23
#
#           continent
# ...

# %%
# same_name = data['Fake_name'].value_counts()
# same_name = pd.DataFrame(same_name)
# same_name[same_name['Fake_name']>=2]

# %%
# import matplotlib.pyplot as plt

# plt.figure(figsize=(20,20))

# data['Fake_name'].value_counts()[:100].plot(kind='bar')

# %%
Fake_data['continent'].unique()
# Out:
# array(['south america', 'europe', 'africa', 'asia', 'oceania'],
#       dtype=object)

# %%
Fake_data[Fake_data['continent'] == 'europe']
# Out:
#                     name  name_num Fake_start_name     Fake_end_name  2022age  \
# 1                 De Gea         1               D            De Gea       31
# 3           Sergio Ramos         1               S      Sergio Ramos       36
# 4               J. Oblak         2               J             Oblak       29
# 6            David Silva         1               D       David Silva       36
# 7               N. Kanté         2               N             Kanté       31
# ...                  ...       ...             ...               ...      ...
# 8923        T. Gundelund         2               T         Gundelund       20
# 8924   M. Frøkjær-Jensen         2               M    Frøkjær-Jensen       22
# 8928           C. Ehlich         2               C            Ehlich       23
# 8930            J. Milli         2               J             Milli       22
# 8931  N. Christoffersson         2               N   Christoffersson       23
#
#      continent
# 1       europe
# ...

# %%
data.sort_values('value', ascending=False).iloc[:30]
# Out:
#     id                 name  age      continent contract_until position  \
# 0    0             L. Messi   31  south america           2021       ST
# 2    7            L. Suárez   31  south america           2021       ST
# 17  30                 Isco   26         europe           2022       ST
# 1    3               De Gea   27         europe           2020       GK
# 14  26             M. Salah   26         africa           2023       MF
# 18  32             Coutinho   26  south america           2023       ST
# 4    9             J. Oblak   25         europe           2021       GK
# 26  45             P. Pogba   25         europe           2021       MF
# 7   14             N. Kanté   27         europe           2023       MF
# 27  47            R. Lukaku   25         europe           2022       ST
# 16  29           L. Insigne   27         europe           2022       ST
# 11  21            E. Cavani   31  south america           2020       ST
# ...

# %%
# !pip install xlml

# %%
import  numpy as np
import  pandas as pd
import  matplotlib.pyplot as plt
import  os
import  copy
from  tqdm import  tqdm

from bs4 import BeautifulSoup
from  urllib.parse import quote
import urllib.request
import requests
import urllib.parse
from  urllib import parse

import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
import json
import selenium
from selenium import webdriver
# import pyperclip

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
# '''
# Real_code
# '''
# chrome_options = webdriver.ChromeOptions()
# chrome_options.add_experimental_option("detach",True)
# # driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)


# baseurl = 'https://1xbet.whoscored.com/'
# driver = webdriver.Chrome('./chromedriver.exe')
# driver.get(baseurl)

# # driver.implicitly_wait(time_to_wait=1000) # 암묵적 대기, 로딩이 끝나면 바로 다음 코드를 진행
# driver.implicitly_wait(5)
# driver.find_element(By.XPATH, "/html/body/div[1]/div/div[1]/div[3]/div/form/input").click()



# country = []
# team = []
# not_found_name = []

# for i,fake_name in enumerate(Fake_data['Fake_end_name'][:3]):
    
#     try:
#         # 검색기능
#         search_engine = driver.find_element(By.XPATH, "/html/body/div[1]/div/div[1]/div[3]/div/form/input")
#         search_engine.send_keys(fake_name)   #-#-#-#-#
#         driver.implicitly_wait(5)

#         enter = driver.find_element(By.XPATH, "/html/body/div[1]/div/div[1]/div[3]/div/form/div/span")
#         enter.click()
#         driver.implicitly_wait(5)

#         # 진짜 이름 클릭
#         name = driver.find_elements(By.XPATH, '/html/body/div[4]/div[3]/div[1]/div[2]/table/tbody/tr')

#         if len(name[1:]) == 1:
#             real = driver.find_element(By.XPATH, '/html/body/div[4]/div[3]/div[1]/div[2]/table/tbody/tr[2]/td[1]/a')
#             real.click()


#         else:    
#             for i in range(len(name[1:])):
#                 if (str(Fake_data['2022age'][i]) == name[1:][i].text[-2:]):
#                     real = driver.find_element(By.XPATH, f'/html/body/div[4]/div[3]/div[1]/div[2]/table/tbody/tr[{i}+2]/td[1]/a')

#             real.click()
#         driver.implicitly_wait(5)

#         try:

#             # 국적 갖고오기

#             country1 = driver.find_element(By.XPATH, '/html/body/div[4]/div[3]/div[1]/div[1]/div[2]/div[2]/div[6]/span[2]').text
#             country.append(country1)
#             driver.implicitly_wait(5)

#         except:
#             country.append(np.nan)

#         try:
#             # history click

#             history = driver.find_element(By.XPATH, '/html/body/div[4]/div[3]/div[1]/div[2]/ul/li[4]/a')
#             history.click()
#             driver.implicitly_wait(5)

#             # 팀갖고오기
#             team1 = driver.find_element(By.XPATH,'/html/body/div[4]/div[4]/div[1]/div[3]/div').text.split('\n')
#             fake_df = pd.DataFrame(team1)
#             fake_df = fake_df[fake_df[0].str.contains('2017/2018')]
#             team1 = fake_df.iloc[0,:1][0][10:]
#             team.append(team1)

#         except:
#             team.append(np.nan)
#     except:
#         country.append(np.nan)
#         team.append(np.nan)
#         not_found_name.append(fake_name)
#         print(fake_name)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12548\3838529353.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver.exe')
# De Gea

# %%
country
# Out:
# ['Argentina', nan, nan]

# %%
country
# Out:
# [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]

# %%
Fake_data['Fake_end_name'] ==
# Out:
# 0                  Messi
# 1                 De Gea
# 2                 Suárez
# 3           Sergio Ramos
# 4                  Oblak
#               ...
# 8927             Adewusi
# 8928              Ehlich
# 8929             Fuentes
# 8930               Milli
# 8931     Christoffersson
# Name: Fake_end_name, Length: 8932, dtype: object

# %%
real = driver.find_element(By.XPATH, '/html/body/div[4]/div[3]/div[1]/div[2]/table/tbody/tr[2]/td[1]/a')
real.click()

# %%
import selenium
from selenium import webdriver

chrome_options = webdriver.ChromeOptions()
chrome_options.add_experimental_option("detach",True)
# driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)


baseurl = 'https://1xbet.whoscored.com/'
driver = webdriver.Chrome('./chromedriver.exe')
driver.get(baseurl)

# driver.implicitly_wait(time_to_wait=1000) # 암묵적 대기, 로딩이 끝나면 바로 다음 코드를 진행
driver.implicitly_wait(5)
driver.find_element(By.XPATH, "/html/body/div[1]/div/div[1]/div[3]/div/form/input").click()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12548\4049170145.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver.exe')

# %%
search_engine = driver.find_element(By.XPATH, "/html/body/div[1]/div/div[1]/div[3]/div/form/input")
search_engine.send_keys(Fake_data['Fake_end_name'][0])

enter = driver.find_element(By.XPATH, "/html/body/div[1]/div/div[1]/div[3]/div/form/div/span")
enter.click()

# %%
name = driver.find_elements(By.XPATH, '/html/body/div[4]/div[3]/div[1]/div[2]/table/tbody/tr')
name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="79171902ff995c04c202d4ca3743aadc", element="a83a235f-7272-4d83-98fa-ba16b517d44c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="79171902ff995c04c202d4ca3743aadc", element="783b01e7-97d6-4b1d-afaa-dc42201c264a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="79171902ff995c04c202d4ca3743aadc", element="40b21838-9bc8-4fa4-9205-e3c9caf22dbe")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="79171902ff995c04c202d4ca3743aadc", element="845dc1ea-053e-4903-aff4-bcb8995ae7ed")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="79171902ff995c04c202d4ca3743aadc", element="1d739c8b-60bd-4dea-8aee-de1fe2fcc887")>]

# %%
name[2].text
# Out:
# 'Mbida Messi\n41'

# %%
for i in range(3):
    print(name[i].text[:1] == 'L')
# Out:
# False
# True
# False

# %%
name[1:][0].text
# Out:
# 'Joakim Milli\nLecce'

# %%
# name = driver.find_elements(By.XPATH, '/html/body/div[4]/div[3]/div[1]/div[2]/table/tbody/tr')

# for i in range(len(name[1:])):
    
#     if str(Fake_data['2022age'][0]) == name[1:][i].text[-2:]:
#         real = driver.find_element(By.XPATH, f'/html/body/div[4]/div[3]/div[1]/div[2]/table/tbody/tr[{i}+1]')
#         real.click()

# %%
# /html/body/div[4]/div[3]/div[1]/div[2]/table/tbody/tr[2]/td[1]/a

# %%
# 진짜 메시 클릭

name = driver.find_elements(By.XPATH, '/html/body/div[4]/div[3]/div[1]/div[2]/table/tbody/tr')

for i in range(len(name[1:])):
    if (str(Fake_data['2022age'][0]) == name[1:][i].text[-2:]) & (Fake_data['Fake_start_name'][2] == name[1:][i].text[0]):
        print(i)
#         real = driver.find_element(By.XPATH, f'/html/body/div[4]/div[3]/div[1]/div[2]/table/tbody/tr[{i}+2]/td[1]/a')
# real.click()
# Out:
# 0

# %%
Fake_data['2022age'][2] == name[1:][6].text[-2:]
# Out:
# False

# %%
name[1:][2].text
# Out:
# 'Messi Essomba\n32'

# %%
len(name[1:])
# Out:
# 4

# %%
for i in range(len(name[1:])):
    a = name[1:][i].text
    print(a)
# Out:
# Lionel Messi
# Paris Saint-Germain
# 35
# Mbida Messi
# 41
# Messi Essomba
# 32
# Enguene Junior Messi
# 28

# %%
# 국적 갖고오기

country = driver.find_element(By.XPATH, '/html/body/div[4]/div[3]/div[1]/div[1]/div[2]/div[2]/div[6]/span[2]').text
country
# Out:
# 'Argentina'

# %%
# history click

history = driver.find_element(By.XPATH, '/html/body/div[4]/div[3]/div[1]/div[2]/ul/li[4]/a')
history.click()

# %%
# 팀갖고오기

team = driver.find_element(By.XPATH,'/html/body/div[4]/div[4]/div[1]/div[3]/div').text.split('\n')
fake_df = pd.DataFrame(team)
fake_df = fake_df[fake_df[0].str.contains('2017/2018')]
fake_df.iloc[0,:1][0][10:]
# Out:
# 'Barcelona'

# %%
headers={"User-Agent" : "Mozilla/5.0"}

# %%
# import requests
# from bs4 import BeautifulSoup

# url = 'https://1xbet.whoscored.com/Search/?t=messi'

# response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})

# html = response.text
# # soup = BeautifulSoup(html, 'html.parser')
# # soup

# rescode = response.getcode()

# response_body = response.read()
# respponse_body = json.loads(response_body)

# resultdata = response_body['items']
# resultdata
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [96], in <cell line: 12>()
#       8 html = response.text
#       9 # soup = BeautifulSoup(html, 'html.parser')
#      10 # soup
# ---> 12 rescode = response.getcode()
#      14 response_body = response.read()
#      15 respponse_body = json.loads(response_body)
#
# AttributeError: 'Response' object has no attribute 'getcode'

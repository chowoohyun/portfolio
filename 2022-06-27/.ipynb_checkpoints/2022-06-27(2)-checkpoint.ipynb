# %%
import tensorflow as tf

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

np.shape(x_train)
# Out:
# (60000, 28, 28)

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=5)

model.evaluate(x_test,  y_test, verbose=2)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 2s 782us/step - loss: 0.2962 - accuracy: 0.9145
# Epoch 2/5
# 1875/1875 [==============================] - 1s 776us/step - loss: 0.1423 - accuracy: 0.9580
# Epoch 3/5
# 1875/1875 [==============================] - 1s 791us/step - loss: 0.1068 - accuracy: 0.9680
# Epoch 4/5
# 1875/1875 [==============================] - 1s 794us/step - loss: 0.0871 - accuracy: 0.9733
# Epoch 5/5
# 1875/1875 [==============================] - 1s 779us/step - loss: 0.0733 - accuracy: 0.9767
# 313/313 - 0s - loss: 0.0757 - accuracy: 0.9787 - 230ms/epoch - 736us/step
# [0.07566048949956894, 0.9786999821662903]

# %%
# 미스난 데이터를 찾아야 한다! 못 맞춘건 뭐냐?
# 1, 코딩으로 하나씩 찾아내기
# 2. 평가표를 만들어서 찾아내기
# 3. 평가표는 머신러닝과 비슷하기 때문에

# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
img = Image.open('num.png').convert('L')
img = img.resize((28,28))

arr = (255-np.array(img))/255.
print(np.shape(img))
plt.imshow(arr, cmap='gray')
arr.min(), arr.max()

pr = model.predict(arr.reshape(-1,28,28))
np.argmax(pr)
# Out:
# (28, 28)
# 1/1 [==============================] - 0s 47ms/step
# 3

# %% [markdown]
# ### 지금까지 배운 것
#
# 배열 array의 이해
# 배열 구조 변경 ( reshape, newaxis, flatten)</br>
# 확장(expand) // 행,열 연결(vstack, hstack)
#
# expand 와 append는 좀 다르기 때문에 항상 같이 보기

# %% [markdown]
# ### Numpy 브로드캐스팅 강의
#
# 예습 - 배열의 구조가 일정한 조건을 맞추면, 자동으로 확장하여 연산을 시행한다.

# %%
x = [[1,20],[2,15],[1,20]]
w = np.array([[3,3],[3,3],[3,3]])

x*w
# Out:
# array([[ 3, 60],
#        [ 6, 45],
#        [ 3, 60]])

# %%
#자료의 갯수가 많아지면 곱하거나 더하기가 힘들어진다.
#그러므로 브로드캐스팅을 사용하여 전체적으로 곱해준다.

w2 = np.array([3,3])
w3 = np.array(3)
x*w, x*w2,x*w3 

#디멘션은 최댓값을 따라서 간다.
# x(디멘션2) * W(디멘션4) = (디멘션4)

#y_hat
#디멘션에 따라 출력되는 결과가 달라진다.
w4 = np.array([[3]])

np.sum(x*w4, axis=1)

#dot 는 내적곱 => 행렬 연산식에 맞춰서 내용물이 들어가줘야 한다.
#선형대수학의 행렬곱
#이런것들은 어디에 쓰이는가
# Out:
# array([63, 51, 63])

# %%
img1 = Image.open('dark.jpg')
print(img1.size) # 열 너비 570, 행높이 379
np.shape(img1) #사이즈와  반대로 나온다.
#(379, 570, 3) ==> 3 = [r,g,b] 가 570개로 한줄로 만들어져 있으며, 379줄이 이루어져있다.
#[0] => 379 중에서 한줄만 보겠다, [0][0] => 맨앞의 한줄의 한줄만 보겠다.

#나중에 openCV는 어레이 형태로 들어온다.

img1 = np.array(img1)
plt.imshow(img1[:150,])

img2 = img1 + 100 # 브로드캐스팅

plt.imshow(img2) #사진을 흐리게 하거나 진하게 하는것이 이기능

plt.imshow(img1*[1,0,0]) # 색상값에 있어서 필요한 색상만 살릴때 1 0 0 red, 0 1 0 그린

# 사진에 여러가지 작업을 해야 한다.

np.mean(img1) #중간값을 확인하고 평균값을 빼주면된다.

np.mean(img1), np.std(img1) #np.std는 표준편차 함수
# Out:
# (570, 379)
# (34.788685213473435, 34.39067022380647)

# %%
img1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=570x379>

# %%
img3 = Image.open('bri.jpg')
print(img3.size)
img3 = np.array(img3)
np.mean(img3), np.std(img3)
# Out:
# (1300, 876)
# (216.13288871326543, 35.37742208999331)

# %%
img1 = Image.open('dark.jpg')
img1 = img1.resize((240,200))
img1 = np.array(img1)

img2 = Image.open('bri.jpg')
img2 = img1.resize((240,200))
img2 = np.array(img2)

img1[:,:100] = img2[:,:100]

plt.imshow(img1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [29], in <cell line: 9>()
#       6 img2 = img1.resize((240,200))
#       7 img2 = np.array(img2)
# ----> 9 img1[:,:100] = img2[:,:100]
#      11 plt.imshow(img1)
#
# IndexError: too many indices for array: array is 0-dimensional, but 2 were indexed

# %%
img1 = Image.open('dark.jpg')
img1 = img1.resize((240,200)) # np.shape 하면 200, 240 나온다
img1 = np.array(img1)

# 빨간 배경을 크게 해서 이미지 덮씌우기

img1[:,:10]= [255,0,0]
img1[:10,:] = [255,0,0]
img1 [190:,:] =[255,0,0]
img1[:,230:]=[255,0,0]

plt.imshow(img1)

# 권장하진 않음

# %%
img1 = Image.open('dark.jpg')
img1 = img1.resize((240,200)) # np.shape 하면 200, 240 나온다
img1 = np.array(img1)

back = np.zeros((200,240,3), dtype=np.int16)
#만들때 정수냐 실수냐도 중요하기 때문에 dtype 도 체크하고 해야한다.
back[...] = [255,0,0]
back[10:190,10:230] = img1[10:190,10:230]

# 중간에 자동화를 하려면 변수로 지정해서 저장해주는게 좋다.
# ex = num == 10, row 같은 변수를 설정해서 쉽게 해야한다.

plt.imshow(back)

# 두 사진의 숫자값의 타입이 달라서 안맞는다.

# %%
bac
# Out:
# array([[255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.],
#        [255.,   0.,   0.]])
